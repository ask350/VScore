# %% [markdown]
# # Class in Object Oriented Programming
# 1. Class is just like a blueprint to define anything in python
# 2. Objects are specific instances of classes
# ![image.png](attachment:image.png)

# %%
a = 23
print(type(a))
# Out:
# <class 'int'>

# %%
b = 45.3
print(type(b))
# Out:
# <class 'float'>

# %%
c = "ETLHive"
print(type(c))
# Out:
# <class 'str'>

# %%
d = True
print(type(d))
# Out:
# <class 'bool'>

# %%
e = [1, 2, 3, "Example", True]
print(type(e))
# Out:
# <class 'list'>

# %% [markdown]
# # Creating a user defined class
# ![image.png](attachment:image.png)

# %%
class Person:

    # Always define constructor function to define attributes
    def __init__(self, name, age, gender, occupation):   # init stands for initialization
        self.name = name
        self.age = age
        self.gender = gender
        self.occupation = occupation

    # Add a user defined method ( in class function is called method)
    def introduce(self):
        print(f'Hi there my name is {self.name}.')
        print(f'I am {self.age} years old.')
        print(f'I am a {self.gender}.')
        print(f'I work as a {self.occupation}.')

# %% [markdown]
# # Creating the objects for class Person

# %%
p1 = Person("Sarthak", 23, "Male", "Engineer")

# %%
p1

# %%
print(type(p1))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# # Accessing the attributes of class

# %%
p1.name
# Out:
# 'Sarthak'

# %%
p1.age
# Out:
# 23

# %%
p1.gender
# Out:
# 'Male'

# %%
p1.occupation
# Out:
# 'Engineer'

# %% [markdown]
# # Call the introduce function for p1

# %%
p1.introduce()
# Out:
# Hi there my name is Sarthak.
# I am 23 years old.
# I am a Male.
# I work as a Engineer.

# %% [markdown]
# # Creating another personusing keyword argument

# %%
p2 = Person(
    occupation="HR",
    name= "Aditi",
    age=27,
    gender="Female"
)

# %%
print(type(p2))
# Out:
# <class '__main__.Person'>

# %%
p2.name
# Out:
# 'Aditi'

# %%
p2.age
# Out:
# 27

# %%
p2.gender
# Out:
# 'Female'

# %%
p2.occupation
# Out:
# 'HR'

# %%
p2.introduce()
# Out:
# Hi there my name is Aditi.
# I am 27 years old.
# I am a Female.
# I work as a HR.

# %%
p3 = Person("Rahul", 35, "Male", "Admin")

# %%
for i in [p1, p2, p3]:
    i.introduce()
    print('\n=================================\n')
# Out:
# Hi there my name is Sarthak.
# I am 23 years old.
# I am a Male.
# I work as a Engineer.
#
# ...
#
# Hi there my name is Aditi.
# I am 27 years old.
# I am a Female.
# I work as a HR.
#
# ...
#
# Hi there my name is Rahul.
# I am 35 years old.
# I am a Male.
# I work as a Admin.
#
# ...

# %% [markdown]
# # Bank Account example
# ![image.png](attachment:image.png)

# %%
class Account:

    def __init__(self, ac_no, name, bal=0):
        self.ac_no = ac_no
        self.name = name 
        self.bal = bal

    def current_balance(self):
        print(f"Current Balance is : {self.bal} INR")

    def deposit(self, amt):
        # Money will get added in the user account
        self.bal = self.bal + amt
        # Print the balance 
        print(f"Amount of {amt} INR got deposited in account {self.ac_no}")
        self.current_balance()

    def withdraw(self, amt):
        if amt <= self.bal:
            self.bal = self.bal - amt 
            print(f"Amount of {amt} INR got withdrawn from account {self.ac_no}")
        else:
            print("Insufficient balance for Withdrawal")
        self.current_balance()

    def transfer(self, ac2, amt):
        if amt <= self.bal:
            self.bal = self.bal - amt
            ac2.bal = ac2.bal + amt 
            print(f"Amount of {amt} INR got transferred from {self.ac_no} to {ac2.ac_no}")
        else:
            print("Insufficient Balance for Transfer")
        self.current_balance()

# %%
ac1 = Account(9876, "Raman", 3000)
print(type(ac1))
# Out:
# <class '__main__.Account'>

# %%
ac1.ac_no
# Out:
# 9876

# %%
ac1.name
# Out:
# 'Raman'

# %%
ac1.bal
# Out:
# 3000

# %%
ac1.current_balance()
# Out:
# Current Balance is : 3000 INR

# %%
ac1.deposit(1500)
# Out:
# Amount of 1500 INR got deposited in account : 9876
# Current Balance is : 4500 INR

# %%
ac1.bal
# Out:
# 4500

# %%
ac1.withdraw(5000)
# Out:
# Insufficient balance for Withdrawal
# Current Balance is : 4500 INR

# %%
ac1.withdraw(2500)
# Out:
# Amount of 2500 INR got withdrawn account : 9876
# Current Balance is : 2000 INR

# %%
ac1.bal
# Out:
# 2000

# %%
ac2 = Account(1234, "Priya")

# %%
ac2.ac_no
# Out:
# 1234

# %%
ac2.name
# Out:
# 'Priya'

# %%
ac2.bal
# Out:
# 0

# %% [markdown]
# # Transfer from ramans account to priya (ac1 -> ac2)

# %%
ac1.transfer(ac2, 3000)
# Out:
# Insufficient Balance for Transfer
# Current Balance is : 2000 INR

# %%
ac1.bal
# Out:
# 2000

# %%
ac2.bal
# Out:
# 0

# %%
ac1.transfer(ac2, 1200)
# Out:
# Amount of 1200 INR got transferred from 9876 to 1234
# Current Balance is : 800 INR

# %%
ac1.bal
# Out:
# 800

# %%
ac2.bal
# Out:
# 1200

# %% [markdown]
# # Transfer ac2 -> ac1

# %%
ac2.ac_no
# Out:
# 1234

# %%
ac2.transfer(ac1, 1500)
# Out:
# Insufficient Balance for Transfer
# Current Balance is : 1200 INR

# %%
ac2.transfer(ac1, 800)
# Out:
# Amount of 800 INR got transferred from 1234 to 9876
# Current Balance is : 400 INR

# %%
ac2.bal
# Out:
# 400

# %%
ac1.bal
# Out:
# 1600
