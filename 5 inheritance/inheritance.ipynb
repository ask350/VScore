# %% [markdown]
# # Inheritance
#
# Child class will use the methods and attributes of its parent/super class
#
# Polymorphism : applicable to functions, operators and classes
#
# Inheritance : applicable to classes ONLY

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 1. Single Inheritance
#
# i.e 1 Parent class and 1 Child class

# %%
class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f'Hi my name is {self.name}. I am {self.age} years old')

# %%
class Employee(Person):

    def __init__(self, name, age, company):
        super().__init__(name, age)
        self.company = company

    def work(self):
        print(f'I work at {self.company}.')

# %%
p = Person("Sarthak", 27)
type(p)
# Out:
# __main__.Person

# %% [markdown]
# `__main__`  refers to current file that we are working in

# %% [markdown]
# ## \__main__  refers to current file that we are working in

# %%
p.name
# Out:
# 'Sarthak'

# %%
p.age
# Out:
# 27

# %%
p.introduce()
# Out:
# Hi my name is Sarthak. I am 27 years old

# %%
e = Employee("Aditi", 25, "TCS")
type(e)
# Out:
# __main__.Employee

# %%
e.name
# Out:
# 'Aditi'

# %%
e.age
# Out:
# 25

# %%
e.company
# Out:
# 'TCS'

# %%
p.company
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 p.company
#
# AttributeError: 'Person' object has no attribute 'company'

# %% [markdown]
# ### parent class does not have any attribute called company but of sub/child class (Employee) has it

# %%
e.work()
# Out:
# I work at TCS.

# %%
e.introduce()
# Out:
# Hi my name is Aditi. I am 25 years old

# %%
e.introduce()
e.work()
# Out:
# Hi my name is Aditi. I am 25 years old
# I work at TCS.

# %%
p2 = Person(23, 34)

# %%
p2.name
# Out:
# 23

# %%
p2.age
# Out:
# 34

# %%
p2.introduce()
# Out:
# Hi my name is 23. I am 34 years old

# %%
# in above example the name and age both are numbers and we use pydantic for data validation

# %% [markdown]
# ### Pydantic (library from python) for data validation

# %%
# %pip install pydantic
# Out:
# Collecting pydantic
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      --------- --------------------------- 30.7/125.2 kB 660.6 kB/s eta 0:00:01
#      ------------------------ ------------ 81.9/125.2 kB 762.6 kB/s eta 0:00:01
#      --------------------------- --------- 92.2/125.2 kB 751.6 kB/s eta 0:00:01
#      -----------------------------------  122.9/125.2 kB 654.9 kB/s eta 0:00:01
#      ------------------------------------ 125.2/125.2 kB 566.2 kB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic)
#   Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\vscode\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/423.9 kB ? eta -:--:--
#    ------- -------------------------------- 81.9/423.9 kB 1.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 122.9/423.9 kB 1.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 174.1/423.9 kB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 245.8/423.9 kB 1.3 MB/s eta 0:00:01
#    ------------------------- -------------- 266.2/423.9 kB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 327.7/423.9 kB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 348.2/423.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  419.8/423.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 423.9/423.9 kB 1.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.9 MB 2.6 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.9 MB 1.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.9 MB 1.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.9 MB 1.7 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.9 MB 1.4 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/1.9 MB 1.3 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/1.9 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.9 MB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.9 MB 1.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/1.9 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.9 MB 1.5 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.2/1.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.9 MB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/1.9 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.7/1.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.2 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: pydantic-core, annotated-types, pydantic
# Successfully installed annotated-types-0.7.0 pydantic-2.8.2 pydantic-core-2.20.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pydantic email-validator
# Out:
# Requirement already satisfied: pydantic in c:\vscode\repository\venv\lib\site-packages (2.8.2)
# Collecting email-validator
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\vscode\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\vscode\repository\venv\lib\site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\vscode\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Collecting dnspython>=2.0.0 (from email-validator)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in c:\vscode\repository\venv\lib\site-packages (from email-validator) (3.7)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: dnspython, email-validator
# Successfully installed dnspython-2.6.1 email-validator-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Restart and run all cells

# %%
from pydantic import BaseModel

# %%
type(BaseModel)
# Out:
# pydantic._internal._model_construction.ModelMetaclass

# %%
class Student(BaseModel):
    roll_no : int
    name : str
    marks : float
    passed : bool

# %%
s1 = Student(
    roll_no = 501,
    name = "Raman",
    marks = 98.3,
    passed = True
)

# %%
s1.marks
# Out:
# 98.3

# %%
s1.name
# Out:
# 'Raman'

# %%
s1.passed
# Out:
# True

# %%
s2 = Student(
    roll_no = "a403",
    name =23,
    marks =False,
    passed = 43.5
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s2 = Student(
#       2     roll_no = "a403",
#       3     name =23,
#       4     marks =False,
#       5     passed = 43.5
#       6 )
#
# File c:\VSCode\repository\venv\Lib\site-packages\pydantic\main.py:193, in BaseModel.__init__(self, **data)
#     191 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 3 validation errors for Student
# roll_no
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='a403', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/int_parsing
# name
#   Input should be a valid string [type=string_type, input_value=23, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# passed
#   Input should be a valid boolean [type=bool_type, input_value=43.5, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/bool_type

# %%
from pydantic import EmailStr

# %%
class Customer(BaseModel):
    cust_id : int
    name : str
    email : EmailStr

# %%
c1 = Customer(
    cust_id = 1,
    name = "Rahul",
    email = "example@gmail.com"
)

# %%
c1.cust_id
# Out:
# 1

# %%
c1.name
# Out:
# 'Rahul'

# %%
c1.email
# Out:
# 'example@gmail.com'

# %%
c2 = Customer(
    cust_id = 2,
    name = "Priyanka",
    email = "priyag1"
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 c2 = Customer(
#       2     cust_id = 2,
#       3     name = "Priyanka",
#       4     email = "priyag1"
#       5 )
#
# File c:\VSCode\repository\venv\Lib\site-packages\pydantic\main.py:193, in BaseModel.__init__(self, **data)
#     191 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 1 validation error for Customer
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='priyag1', input_type=str]

# %% [markdown]
# ### Multilevel Inheritance
# 1 Parent class, child class and multiple grandchild classes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Employee:

    def __init__(self, emp_id, name):
        self.emp_id = emp_id
        self.name = name

    def get_employee_details(self):
        print(f'Employee Id : {self.emp_id}, Name : {self.name}')

# %%
class Manager(Employee):

    def __init__(self, emp_id, name, dept):
        super().__init__(emp_id, name)
        self.dept = dept

    def get_manager_details(self):
        print(f'Department : {self.dept}')

# %%
class ProjectManager(Manager):

    def __init__(self, emp_id, name, dept, project):
        super().__init__(emp_id, name, dept)
        self.project = project

    def get_project_details(self):
        print(f'Project : {self.project}')

# %%
emp = Employee(101, "Sarthak")
type(emp)
# Out:
# __main__.Employee

# %%
emp.name
# Out:
# 'Sarthak'

# %%
emp.get_employee_details()
# Out:
# Employee Id : 101, Name : Sarthak

# %%
m = Manager(102, "Raman", "Sales")
type(m)
# Out:
# __main__.Manager

# %%
m.emp_id
# Out:
# 102

# %%
m.name
# Out:
# 'Raman'

# %%
m.dept
# Out:
# 'Sales'

# %%
m.get_manager_details()
# Out:
# Department : Sales

# %%
pm = ProjectManager(105,"Aditi", "Engg.", "JLR")
type(pm)
# Out:
# __main__.ProjectManager

# %%
pm.emp_id
# Out:
# 105

# %%
pm.name
# Out:
# 'Aditi'

# %%
pm.dept
# Out:
# 'Engg.'

# %%
pm.project
# Out:
# 'JLR'

# %%
pm.get_employee_details()
pm.get_manager_details()
pm.get_project_details()
# Out:
# Employee Id : 105, Name : Aditi
# Department : Engg.
# Project : JLR

# %% [markdown]
# # Hierarchial Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class User:

    def __init__(self, username, email):
        self.username = username
        self.email = email
        
    def get_user_info(self):
        print(f'Username : {self.username}, Email : {self.email}')

# %%
class AdminUser(User):

    def __init__(self, username, email, access):
        super().__init__(username, email)
        self.access = access

    def get_access_level(self):
        print(f'Access Level : {self.access}')

# %%
class RegularUser(User):

    def __init__(self, username, email, subscribed):
        super().__init__(username, email)
        self.subscribed = subscribed

    def get_sub_info(self):
        print(f'Subscription : {self.subscribed}')

# %%
u1 = User('johndoe123', 'john@gmail.com')
type(u1)
# Out:
# __main__.User

# %%
u1.username
# Out:
# 'johndoe123'

# %%
u1.email
# Out:
# 'john@gmail.com'

# %%
u1.get_user_info()
# Out:
# Username : johndoe123, Email : john@gmail.com

# %%
a1 = AdminUser('admin1', 'admin1@netflix.com', 'partial')
type(a1)
# Out:
# __main__.AdminUser

# %%
a1.get_user_info()
# Out:
# Username : admin1, Email : admin1@netflix.com

# %%
a1.get_access_level()
# Out:
# Access Level : partial

# %%
r1 = RegularUser('aditim3', 'aditi@gmail.com', 'paid-yearly')
type(r1)
# Out:
# __main__.RegularUser

# %%
r1.username
# Out:
# 'aditim3'

# %%
r1.email
# Out:
# 'aditi@gmail.com'

# %%
r1.subscribed
# Out:
# 'paid-yearly'

# %%
r1.access
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 r1.access
#
# AttributeError: 'RegularUser' object has no attribute 'access'

# %%
# because regular user has no admin access

# %%
a1.subscribed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 a1.subscribed
#
# AttributeError: 'AdminUser' object has no attribute 'subscribed'

# %%
r1.get_user_info()
# Out:
# Username : aditim3, Email : aditi@gmail.com

# %%
r1.get_sub_info()
# Out:
# Subscription : paid-yearly

# %%
r1.get_access_level()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 r1.get_access_level()
#
# AttributeError: 'RegularUser' object has no attribute 'get_access_level'

# %%
r1.get_user_info()
# Out:
# Username : aditim3, Email : aditi@gmail.com

# %% [markdown]
# # we can mix and match these inheritance type as required
